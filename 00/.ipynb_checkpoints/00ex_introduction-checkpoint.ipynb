# %% [markdown]
# 1. **The MickeyMouse problem**
#
# a) Write a program that prints the numbers from 1 to 100. But for multiples of 3 print `Mickey` instead of the corresponding number and for the multiples of 5 print `Mouse`. For numbers which are multiples of both three and five print `MickeyMouse`
#
# b) Put the result in a tuple and substitute `Mickey` with `Donald` and `Mouse` with `Duck`

# %%
num = [i for i in range(1, 101, 1)]

num1 = ["MickeyMouse" if (i % 3 == 0 and i % 5 == 0) 
        else "Mickey" if (i % 3 == 0) 
        else "Mouse" if (i % 5 == 0) 
        else i 
        for i in num]

print(num1, "\n")

num2 = ["Donald" if (i == "Mickey")
        else "Duck" if (i == "Mouse")
        else "DonaldDuck" if (i == "MickeyMouse")
        else i 
        for i in num1]

t = tuple(num2)
print(t)
# Out:
# [1, 2, 'Mickey', 4, 'Mouse', 'Mickey', 7, 8, 'Mickey', 'Mouse', 11, 'Mickey', 13, 14, 'MickeyMouse', 16, 17, 'Mickey', 19, 'Mouse', 'Mickey', 22, 23, 'Mickey', 'Mouse', 26, 'Mickey', 28, 29, 'MickeyMouse', 31, 32, 'Mickey', 34, 'Mouse', 'Mickey', 37, 38, 'Mickey', 'Mouse', 41, 'Mickey', 43, 44, 'MickeyMouse', 46, 47, 'Mickey', 49, 'Mouse', 'Mickey', 52, 53, 'Mickey', 'Mouse', 56, 'Mickey', 58, 59, 'MickeyMouse', 61, 62, 'Mickey', 64, 'Mouse', 'Mickey', 67, 68, 'Mickey', 'Mouse', 71, 'Mickey', 73, 74, 'MickeyMouse', 76, 77, 'Mickey', 79, 'Mouse', 'Mickey', 82, 83, 'Mickey', 'Mouse', 86, 'Mickey', 88, 89, 'MickeyMouse', 91, 92, 'Mickey', 94, 'Mouse', 'Mickey', 97, 98, 'Mickey', 'Mouse']
#
# ...

# %% [markdown]
# 2\. **The swap function**
#
# Write a function that swap the values of two input variables x and y (whatever the type). Try to do that also without a temporary variable

# %%
# 1. With temporary variable

def swap(x, y):
    a = x
    x = y
    y = a
    return x, y

x, y = 1, 2
x, y = swap(x, y)
print(f"x value: {x} \n y value: {y}" )
# Out:
# x value: 2
#  y value: 1

# %%
# 2. Without temporary variable

def swap(x, y):
    return y, x

x, y = 1, 2
x, y = swap(x, y)
print(f"x value: {x} \n y value: {y}" )
# Out:
# x value: 2
#  y value: 1

# %% [markdown]
# 3\. **Computing the distance**
#
# Write a function that calculates and returns the euclidean distance between two points *u* and *v*, where *u* and *v* are both 2-tuples *(x,y)*. For example, if *u=(3,0)* and *v=(0,4)*, the function should return 5

# %%
import numpy as np

def distance(u, v):
    return np.sqrt(np.dot(u, u) + np.dot(v, v) - 2 * np.dot(u, v)) 

u, v = (3, 1), (0, 4)
print(distance(u, v))
# Out:
# 4.242640687119285

# %% [markdown]
# 4\. **Counting letters**
#
# Write a program to calculate the number of times each character occurs in a given string *s*. Ignore differneces in capitalization

# %%
s="Write a program that prints the numbers from 1 to 100. \
But for multiples of three print Mickey instead of the number and for the multiples of five print Mouse. \
For numbers which are multiples of both three and five print MickeyMouse"

# ignorign capitalization difference:
s = s.lower()
print(s)
# Out:
# write a program that prints the numbers from 1 to 100. but for multiples of three print mickey instead of the number and for the multiples of five print mouse. for numbers which are multiples of both three and five print mickeymouse

# %%
def count_char(s):
    l = np.unique([x for x in s]) # list of unique characters
    print(f"Different characters in list: \n {l}")
    for x in l:
        print(f"Character {x} counted {s.count(x)} times")

count_char(s)
# Out:
# Different characters in list:
#  [' ' '.' '0' '1' 'a' 'b' 'c' 'd' 'e' 'f' 'g' 'h' 'i' 'k' 'l' 'm' 'n' 'o'
#  'p' 'r' 's' 't' 'u' 'v' 'w' 'y']
# Character   counted 41 times
# Character . counted 2 times
# Character 0 counted 2 times
# Character 1 counted 2 times
# Character a counted 7 times
# Character b counted 5 times
# Character c counted 3 times
# Character d counted 3 times
# Character e counted 22 times
# Character f counted 10 times
# Character g counted 1 times
# Character h counted 9 times
# Character i counted 14 times
# Character k counted 2 times
# Character l counted 6 times
# Character m counted 12 times
# Character n counted 10 times
# Character o counted 13 times
# Character p counted 8 times
# Character r counted 17 times
# Character s counted 9 times
# Character t counted 19 times
# Character u counted 9 times
# Character v counted 2 times
# Character w counted 2 times
# Character y counted 2 times

# %% [markdown]
# 5\. **Isolating the unique**
#
# Write a function that determines and count the unique numbers in the list *l*

# %%
l = [36, 45, 58, 3, 74, 96, 64, 45, 31, 10, 24, 19, 33, 86, 99, 18, 63, 70, 85,
 85, 63, 47, 56, 42, 70, 84, 88, 55, 20, 54, 8, 56, 51, 79, 81, 57, 37, 91,
 1, 84, 84, 36, 66, 9, 89, 50, 42, 91, 50, 95, 90, 98, 39, 16, 82, 31, 92, 41,
 45, 30, 66, 70, 34, 85, 94, 5, 3, 36, 72, 91, 84, 34, 87, 75, 53, 51, 20, 89, 51, 20]

print(len(l))

def unique(l):
    l_unique = np.unique(l)
    print(l_unique, "\n", f"There are {len(l_unique)} unique numbers")

unique(l)
# Out:
# 80
# [ 1  3  5  8  9 10 16 18 19 20 24 30 31 33 34 36 37 39 41 42 45 47 50 51
#  53 54 55 56 57 58 63 64 66 70 72 74 75 79 81 82 84 85 86 87 88 89 90 91
#  92 94 95 96 98 99]
#  There are 54 unique numbers

# %%
# Without the pre-bulit function
l_unique = []

def unique(l):
    for x in l: 
        if (np.isin(x, l_unique)):
            continue
        else:
            l_unique.append(x)
    print(np.sort(l_unique), "\n", f"There are {len(l_unique)} unique numbers")

unique(l)
# Out:
# [ 1  3  5  8  9 10 16 18 19 20 24 30 31 33 34 36 37 39 41 42 45 47 50 51
#  53 54 55 56 57 58 63 64 66 70 72 74 75 79 81 82 84 85 86 87 88 89 90 91
#  92 94 95 96 98 99]
#  There are 54 unique numbers

# %% [markdown]
# 6\. **Combination of functions**
#
# Write two functions - one that returns the square of a number, and one that returns the cube. Now write a third function that returns the number raised to the 6th power using the two previous functions.

# %%
def square(x):
    return x * x

def cube(x):
    return x * x * x

x = 2
print(f"{x} ^ 6 = {cube(square(x))}")
# Out:
# 2 ^ 6 = 64

# %% [markdown]
# 7\. **Cubes**
#
# Create a list of the cubes of x for x in *[0, 10]* using:
#
# a) a for loop
#
# b) a list comprehension

# %%
num = [x for x in range(11)]

cube1, cube2 = [], []

for x in num:
    cube1.append(pow(x, 3))
print(cube1, "\n")

cube2 = [pow(x, 3) for x in num]
print(cube2)
# Out:
# [0, 1, 8, 27, 64, 125, 216, 343, 512, 729, 1000]
#
# [0, 1, 8, 27, 64, 125, 216, 343, 512, 729, 1000]

# %% [markdown]
# 8\. **Nested list comprehension**
#
# A Pythagorean triple is an integer solution to the Pythagorean theorem $a^2+b^2=c^2$. The first Pythagorean triple is (3,4,5). Find and put in a tuple all unique Pythagorean triples for the positive integers a, b and c less than 100.

# %%
num = [x for x in range(1, 101)] # not considering 0
Pythagorean_triple = []

for i in num:
    for j in num:
        if i > j:  # let's made them unique
            k = np.sqrt(i * i + j * j)
            if (np.abs(k - int(k)) == 0 and k < 100):
                Pythagorean_triple.append((i, j, int(k)))

print(Pythagorean_triple, "\n", f"Number of unique triples under 100 := {len(Pythagorean_triple)}")
# Out:
# [(4, 3, 5), (8, 6, 10), (12, 5, 13), (12, 9, 15), (15, 8, 17), (16, 12, 20), (20, 15, 25), (21, 20, 29), (24, 7, 25), (24, 10, 26), (24, 18, 30), (28, 21, 35), (30, 16, 34), (32, 24, 40), (35, 12, 37), (36, 15, 39), (36, 27, 45), (40, 9, 41), (40, 30, 50), (42, 40, 58), (44, 33, 55), (45, 24, 51), (45, 28, 53), (48, 14, 50), (48, 20, 52), (48, 36, 60), (52, 39, 65), (55, 48, 73), (56, 33, 65), (56, 42, 70), (60, 11, 61), (60, 25, 65), (60, 32, 68), (60, 45, 75), (63, 16, 65), (63, 60, 87), (64, 48, 80), (68, 51, 85), (70, 24, 74), (72, 21, 75), (72, 30, 78), (72, 54, 90), (72, 65, 97), (75, 40, 85), (76, 57, 95), (77, 36, 85), (80, 18, 82), (80, 39, 89), (84, 13, 85), (84, 35, 91)]
#  Number of unique triples under 100 := 50

# %% [markdown]
# 9\. **Normalization**
#
# Write a function that takes a tuple of numbers and returns it with the entries normalized to one

# %%
def normalize(t):
    norm = np.sqrt(np.dot(t, t))
    t_norm = [x / norm for x in t]
    return tuple(t_norm)

t = (3, 4)
print(normalize(t))
# Out:
# (np.float64(0.6), np.float64(0.8))
