# %% [markdown]
# The following exercises are meant to be solved by gathering the bash commands incrimentally in two scripts, one for ex 1.* the other for ex 2.*

# %% [markdown]
# ### Ex 1

# %% [markdown]
# 1\.a Make a new directory called `students` in your home. Download a csv file with the list of students of this lab from [here](https://www.dropbox.com/s/867rtx3az6e9gm8/LCP_22-23_students.csv) (use the `wget` command) and copy that to `students`. First check whether the file is already there

# %% [markdown]
# ```bash
# cd $HOME
# mkdir students
# cd students
# wget https://www.dropbox.com/scl/fi/bxv17nrbrl83vw6qrkiu9/LCP_22-23_students.csv?rlkey=47fakvatrtif3q3qw4q97p5b7&e=1
# mv LCP_22-23_students.csv?rlkey=47fakvatrtif3q3qw4q97p5b7&e=1 LCP_22-23_students.csv # Rename it
# ```

# %% [markdown]
# ```bash
# # check if the file is in the current directory
# find . -name "LCP*"
# ```

# %% [markdown]
# 1\.b Make two new files, one containing the students belonging to PoD, the other to Physics.

# %% [markdown]
# ```bash
# # create two files
# touch PoD_st.csv
# touch P_st.csv
#
# # to see the file
# vim LCP_22-23_students.csv
#
# # find lines with PoD/Physics and redirect it to files
# grep "PoD" LCP_22-23_students.csv >> PoD_st.csv
# grep "Physics" LCP_22-23_students.csv >> Physics_st.csv
# ```

# %% [markdown]
# 1\.c For each letter of the alphabet, count the number of students whose surname starts with that letter.

# %% [markdown]
# ```bash
# # we first remove the first line (column name)
# sed -i  '1d' LCP_22-23_students.csv # sed insert -> first (1) delete (d)
# ```

# %% [markdown]
# ```bash
# # then we loop over all letters
# for i in {A..Z}
# do
#     count=$(grep -c "^$i" LCP_22-23_students.csv) # $(command) makes the output a variable
#     echo "$i : $count times" >> Surname_count.txt # redirect appending in a text file
#
# done
# ```

# %% [markdown]
# 1\.d Find out which is the letter with most counts.

# %% [markdown]
# ```bash
# most_count=0
# most_i=""
#
# for i in {A..Z}
# do
#     count=$(grep -c "^$i" LCP_22-23_students.csv)
#
#     if [ $count -gt $most_count ]; then
#         most_count=$count
#         most_i=$i
#     fi
# done
#
# echo "Most counted letter: $most_i counted $most_count times."
# ```

# %% [markdown]
# 1\.e Assume an obvious numbering of the students in the file (first line is 1, second line is 2, etc.), group students "modulo 18", i.e. 1,19,37,.. 2,20,38,.. etc. and put each group in a separate file

# %% [markdown]
# ```bash
# # Let's count the number of lines
# n=$(grep -c "" LCP_22-23_students.csv)
#
# # Let's numerate students
# for (( i=1; i<=n; i++ ))
# do
#     echo "$i,$(sed -n "${i}p" LCP_22-23_students.csv)" >> numbered_LCP_22-23_students.csv
# done
# ```

# %% [markdown]
# ```bash
# mkdir Mod18
# n=$(grep -c "" LCP_22-23_students.csv)
#
# for (( i=1; i<=18; i++))
# do
#     j=$i
#     while [ $j -lt $n ]
#     do
#         echo "$(sed -n "${j}p" numbered_LCP_22-23_students.csv)" >> LCP_22-23_students_Mod18_${i}.csv
#         j=$(($j + 18))
#     done
#     mv LCP_22-23_students_Mod18_${i}.csv Mod18
# done
# ```

# %% [markdown]
# If we want an entire script for es1
#
# ```bash
# #!/bin/bash
#
# #1b
# touch PoD_st.csv
# touch P_st.csv
# grep "PoD" LCP_22-23_students.csv >> PoD_st.csv
# grep "Physics" LCP_22-23_students.csv >> Physics_st.csv
#
# #1c
# sed -i  '1d' LCP_22-23_students.csv # sed insert -> first (1) delete (d)
# for i in {A..Z}
# do
#     count=$(grep -c "^$i" LCP_22-23_students.csv) # $(command) makes the output a variable
#     echo "$i : $count times" >> Surname_count.txt # redirect appending in a text file
# done
#
# #1d
# most_count=0
# most_i=""
# for i in {A..Z}
# do
#     count=$(grep -c "^$i" LCP_22-23_students.csv)
#
#     if [ $count -gt $most_count ]; then
#         most_count=$count
#         most_i=$i
#     fi
# done
# echo "Most counted letter: $most_i counted $most_count times."
#
# #1e
# mkdir Mod18
# n=$(grep -c "" LCP_22-23_students.csv)
#
# for (( i=1; i<=18; i++))
# do
#     j=$i
#     while [ $j -lt $n ]
#     do
#         echo "$(sed -n "${j}p" numbered_LCP_22-23_students.csv)" >> LCP_22-23_students_Mod18_${i}.csv
#         j=$(($j + 18))
#     done
#     mv LCP_22-23_students_Mod18_${i}.csv Mod18
# done
# ```
#
# Then in terminal do:
# ```bash
# mkdir students
# cd students
# wget https://www.dropbox.com/scl/fi/bxv17nrbrl83vw6qrkiu9/LCP_22-23_students.csv?rlkey=47fakvatrtif3q3qw4q97p5b7&e=1
# mv LCP_22-23_students.csv?rlkey=47fakvatrtif3q3qw4q97p5b7&e=1 LCP_22-23_students.csv # Rename it
# ```
#
# Then create the .sh file for the script
# ```bash
# touch student.sh #create
# echo "..script.." >> student.sh #edit
# chmod +x student.sh #compile
# ./student.sh #execute
# ```

# %% [markdown]
# ### Ex 2

# %% [markdown]
# 2.a Make a copy of the file `data.csv` removing the metadata and the commas between numbers; call it `data.txt`

# %% [markdown]
# ```bash
# cp data.csv data.txt
#
# sed -i '/^#/d' data.txt # -i insert in file (-e show in terminal) -> delete what begins with #
# sed -i 's/,//g' data.txt # substituto (,) <-> ( ) globaly
# ```

# %% [markdown]
# 2\.b How many even numbers are there?

# %% [markdown]
# ```bash
# n=$(grep -c '' data.txt) #number of lines
#
# even=0
# for (( i=1; i<=n; i++ )) #loop over rows
# do
#     for (( j=1; j<=6; j++ )) #loop over columns
#     do
#         X=$(sed -n "${i}p" data.txt | cut -f${j} -d " ") # use "" not ''
#         P=$(( $X % 2 ))
#         if [ $P -eq 0 ]; then # -eq to compare numbers
#             even=$(($even + 1))
#         fi
#     done
# done
# echo "There are $even even numbers"
# ```

# %% [markdown]
# 2\.c Distinguish the entries on the basis of `sqrt(X^2 + Y^2 + Z^2)` is greater or smaller than `100*sqrt(3)/2`. Count the entries of each of the two groups

# %% [markdown]
# ```bash
# n=$(grep -c '' data.txt) #number of lines
# gt=0
#
# for (( i=1; i<=n; i++ )); do
#     for (( j=1; j<=2; j++ )); do  # loop over columns
#         jy=$((j+1))
#         jz=$((j+2))
#
#         # extract numbers
#         X=$(sed -n "${i}p" data.txt | cut -f"$j" -d " ")
#         Y=$(sed -n "${i}p" data.txt | cut -f"$jy" -d " ")
#         Z=$(sed -n "${i}p" data.txt | cut -f"$jz" -d " ")
#
#         # sum of squares
#         D=$((X*X + Y*Y + Z*Z))
#
#         # sqrt
#         sqr=$(echo "scale=6; sqrt($D)" | bc)
#         sqr3=$(echo "scale=6; sqrt(3)" | bc)
#
#         # comparison
#         is_gt=$(echo "$sqr > (100*$sqr3/2)" | bc)
#         if [ "$is_gt" -eq 1 ]; then
#             gt=$((gt + 1))
#         fi
#     done
# done
# echo "There are $gt greater than 100*sqrt(3)/2"
# echo "There are $((n*6 - gt)) not greater than 100*sqrt(3)/2"
# ```

# %% [markdown]
# 2\.d Make `n` copies of data.txt (with `n` an input parameter of the script), where the i-th copy has all the numbers divided by i (with `1<=i<=n`).

# %% [markdown]
# ```bash
# N=10 #for example
# n=$(grep -c "" data.txt)
#
# mkdir Data_fracN
# for (( j=1; j<=N; j++ )); do
#     #divide by number and redirect to file
#     touch Data_frac${j}.txt
#     mv Data_frac${j}.txt Data_fracN
#     done
#
# for (( i=1; i<=n; i++ )); do
#     # extract numbers
#     X=$(sed -n "${i}p" data.txt | cut -f1 -d " ")
#     Y=$(sed -n "${i}p" data.txt | cut -f2 -d " ")
#     Z=$(sed -n "${i}p" data.txt | cut -f3 -d " ")
#     X1=$(sed -n "${i}p" data.txt | cut -f4 -d " ")
#     Y1=$(sed -n "${i}p" data.txt | cut -f5 -d " ")
#     Z1=$(sed -n "${i}p" data.txt | cut -f6 -d " ")
#
#     for (( j=1; j<=N; j++ )); do
#     #divide by number and redirect to file
#     Xdiv=$(echo "scale=6; $X / $j" | bc)
#     Ydiv=$(echo "scale=6; $Y / $j" | bc)
#     Zdiv=$(echo "scale=6; $Z / $j" | bc)
#     X1div=$(echo "scale=6; $X1 / $j" | bc)
#     Y1div=$(echo "scale=6; $Y1 / $j" | bc)
#     Z1div=$(echo "scale=6; $Z1 / $j" | bc)
#
#     echo "$Xdiv $Ydiv $Zdiv $X1div $Y1div $Z1div" >> Data_fracN/Data_frac${j}.txt
#     done
# done
# ```

# %% [markdown]
# If we want an entire script for ex2:
#
# ```bash
# #!/bin/bash
#
# #1a
# cp data.csv data.txt
#
# sed -i '/^#/d' data.txt # -i insert in file (-e show in terminal) -> delete what begins with #
# sed -i 's/,//g' data.txt # substituto (,) <-> ( ) globaly
#
# #1b
# n=$(grep -c '' data.txt) #number of lines
#
# even=0
# for (( i=1; i<=n; i++ )) #loop over rows
# do
#     for (( j=1; j<=6; j++ )) #loop over columns
#     do
#         X=$(sed -n "${i}p" data.txt | cut -f${j} -d " ") # use "" not ''
#         P=$(( $X % 2 ))
#         if [ $P -eq 0 ]; then # -eq to compare numbers
#             even=$(($even + 1))
#         fi
#     done
# done
# echo "There are $even even numbers"
#
# #1c
# gt=0
# for (( i=1; i<=n; i++ )); do
#     for (( j=1; j<=2; j++ )); do  # loop over columns
#         jy=$((j+1))
#         jz=$((j+2))
#
#         # extract numbers
#         X=$(sed -n "${i}p" data.txt | cut -f"$j" -d " ")
#         Y=$(sed -n "${i}p" data.txt | cut -f"$jy" -d " ")
#         Z=$(sed -n "${i}p" data.txt | cut -f"$jz" -d " ")
#
#         # sum of squares
#         D=$((X*X + Y*Y + Z*Z))
#
#         # sqrt
#         sqr=$(echo "scale=6; sqrt($D)" | bc)
#         sqr3=$(echo "scale=6; sqrt(3)" | bc)
#
#         # comparison
#         is_gt=$(echo "$sqr > (100*$sqr3/2)" | bc)
#         if [ "$is_gt" -eq 1 ]; then
#             gt=$((gt + 1))
#         fi
#     done
# done
# echo "There are $gt greater than 100*sqrt(3)/2"
# echo "There are $((n*6 - gt)) not greater than 100*sqrt(3)/2"
#
# #1d
# read -p "Enter N:" N
#
# mkdir Data_frac${N}
# for (( j=1; j<=N; j++ )); do
#     #divide by number and redirect to file
#     touch Data_frac${j}.txt
#     mv Data_frac${j}.txt Data_frac${N}
#     done
#
# for (( i=1; i<=n; i++ )); do
#     # extract numbers
#     X=$(sed -n "${i}p" data.txt | cut -f1 -d " ")
#     Y=$(sed -n "${i}p" data.txt | cut -f2 -d " ")
#     Z=$(sed -n "${i}p" data.txt | cut -f3 -d " ")
#     X1=$(sed -n "${i}p" data.txt | cut -f4 -d " ")
#     Y1=$(sed -n "${i}p" data.txt | cut -f5 -d " ")
#     Z1=$(sed -n "${i}p" data.txt | cut -f6 -d " ")
#
#     for (( j=1; j<=N; j++ )); do
#     #divide by number and redirect to file
#     Xdiv=$(echo "scale=6; $X / $j" | bc)
#     Ydiv=$(echo "scale=6; $Y / $j" | bc)
#     Zdiv=$(echo "scale=6; $Z / $j" | bc)
#     X1div=$(echo "scale=6; $X1 / $j" | bc)
#     Y1div=$(echo "scale=6; $Y1 / $j" | bc)
#     Z1div=$(echo "scale=6; $Z1 / $j" | bc)
#
#     echo "$Xdiv $Ydiv $Zdiv $X1div $Y1div $Z1div" >> Data_frac${N}/Data_frac${j}.txt
#     done
# done
# ```
