# %% [markdown]
# # OSEMN Exercises

# %%
# %matplotlib inline
import pandas as pd
import numpy as np

# %% [markdown]
# 1\. Create a random list of number and then save it to a text file named "simple_data.txt"

# %%
random_list = [float(i) for i in np.random.rand(100)]
print(f"Random list: \n {random_list}")
# Out:
# Random list:
# ...

# %%
pwd
# Out:
# '/mnt/c/Users/kevin/Desktop/LaboratoryOfComputationalPhysicsY8/05ex'

# %%
file_name = '/mnt/c/Users/kevin/Desktop/LaboratoryOfComputationalPhysicsY8/05ex/simple_data.txt'
with open(file_name, mode='w') as f: # w -> create + overwrite / a -> append on bottom 
    for item in random_list:
        f.write(f"{item} \n")

with open(file_name, mode='r') as f:
    for line in f:
        print(line)
# Out:
# 0.8078337554332202
#
# 0.7187865390605346
#
# 0.003919516853492566
#
# 0.9044781259842513
#
# 0.6118881020096233
#
# 0.6248677579716019
#
# 0.2420861301763475
#
# 0.7319116202449067
#
# 0.773217375117452
#
# 0.06825160595918867
#
# 0.892864501122236
#
# 0.01769895451128467
#
# 0.7789573231053515
#
# 0.6914647793627681
#
# 0.8762298201737674
#
# 0.9352602025547517
#
# 0.7321025931019989
#
# 0.6831852115499392
#
# 0.38393364430656496
#
# 0.3898548993010633
#
# 0.6897671954782607
#
# 0.6413208438504833
#
# 0.5943187051052568
#
# 0.8998046735444926
#
# 0.5900223083835378
#
# 0.6251796547817605
#
# 0.4407954846401271
#
# 0.9663327416640012
#
# 0.7487568254289301
#
# 0.9465277076126191
#
# 0.6697767642800443
#
# 0.40359583029478596
#
# 0.5765928276832935
#
# 0.4319029205665339
#
# 0.44873651631761413
#
# 0.5687269147834322
#
# 0.01703315875000533
#
# 0.6705868454810117
#
# 0.8821688085703997
#
# 0.6187253117661655
#
# 0.9895137008503372
#
# 0.7057882687329503
#
# 0.0536831771784585
#
# ...

# %% [markdown]
# 2\. Create a random matrix of 5x5 and then save it to a text file named "data.txt"

# %%
matrix = np.random.rand(5,5)
print(matrix)
# Out:
# [[0.5914075  0.53171727 0.54691289 0.20008438 0.00527832]
#  [0.06557298 0.65723451 0.14488253 0.1680816  0.72449695]
#  [0.67327715 0.81164438 0.64657531 0.19376992 0.15563291]
#  [0.95375457 0.09752007 0.9490121  0.21915288 0.80802931]
#  [0.38764661 0.89321465 0.78201852 0.65306202 0.25334101]]

# %%
file_name = '/mnt/c/Users/kevin/Desktop/LaboratoryOfComputationalPhysicsY8/05ex/data.txt'
with open(file_name, mode='w') as f:
    for i in range(matrix.shape[0]):
        for j in range(matrix.shape[1]):
            f.write(f"{str(matrix[i,j])} ") # spacebar to separate
        f.write("\n")

with open(file_name, mode="r") as f:
    for line in f:
        print(line)
# Out:
# 0.5914074982278161 0.5317172670837058 0.5469128878865495 0.20008437927391698 0.005278315817286994
#
# 0.06557298312692916 0.6572345074482593 0.14488253387110195 0.16808159637682274 0.7244969549075124
#
# 0.6732771508150013 0.8116443763922281 0.646575305992671 0.19376991667533283 0.15563291251370137
#
# 0.9537545684197699 0.09752006632866939 0.9490121007383299 0.21915287979538367 0.8080293068612883
#
# 0.38764661449567306 0.8932146504973999 0.7820185153878386 0.6530620161290146 0.25334100788374025

# %% [markdown]
# 3\. Load the saved txt file of point 2 and convert it to a csv file (by hand)

# %%
file_name = '/mnt/c/Users/kevin/Desktop/LaboratoryOfComputationalPhysicsY8/05ex/data.txt'
file_name_csv = '/mnt/c/Users/kevin/Desktop/LaboratoryOfComputationalPhysicsY8/05ex/data.csv'
with open(file_name, mode="r") as txt:
    with open(file_name_csv, mode="w") as csv:
        for line in txt:
            csv.write(f"{line[:-2].replace(" ", ",")}\n") # replace until last 2 letters (" " + "\n") -> dont want line ending with comma
with open(file_name_csv, mode="r") as f:
    for line in f:
        print(line)
# Out:
# 0.5914074982278161,0.5317172670837058,0.5469128878865495,0.20008437927391698,0.005278315817286994
#
# 0.06557298312692916,0.6572345074482593,0.14488253387110195,0.16808159637682274,0.7244969549075124
#
# 0.6732771508150013,0.8116443763922281,0.646575305992671,0.19376991667533283,0.15563291251370137
#
# 0.9537545684197699,0.09752006632866939,0.9490121007383299,0.21915287979538367,0.8080293068612883
#
# 0.38764661449567306,0.8932146504973999,0.7820185153878386,0.6530620161290146,0.25334100788374025

# %% [markdown]
# 4\. load the binary file named *credit_card.dat* and convert the data into the real credit-card number.
# Each line correspond to a credit card number.
# Each character is composed by 6 bit (even the space) and the last 4 bit are just a padding
#
# **hint**: use the `chr()` function to convert a number to a char

# %%
import struct

# %%
file_name = '/mnt/c/Users/kevin/Desktop/LaboratoryOfComputationalPhysicsY8/05ex/credit_card.dat'
list_num = []
list_bin = []

with open(file_name, "rb") as bn:
    file_content = bn.read()
    str_content = file_content.decode('utf-8').replace("\n", "") #tolgo le spaziature

counter = 0
for i in range(0, len(file_content), 10):

    # Prendi i 10 bit del record (MSB first)
    thisBin = str_content[i:i+10]
    list_bin.append(thisBin)

    # Estrazione blocchi da 6 bit saltando 4, MSB-first
    list_num.append(int(thisBin[:6], 2)) #in base due

    counter += 1
    if counter > 500:
        break

# %%
print(list_num)
print(list_bin)
# Out:
# [55, 45, 34, 53, 45, 14, 51, 61, 22, 50, 45, 6, 15, 53, 56, 35, 52, 56, 15, 53, 8, 11, 54, 42, 45, 11, 32, 12, 3, 32, 12, 7, 32, 45, 23, 43, 54, 44, 3, 48, 44, 3, 55, 12, 3, 49, 28, 44, 19, 50, 12, 27, 56, 12, 19, 50, 13, 31, 50, 53, 12, 30, 50, 12, 30, 56, 62, 22, 55, 60, 14, 23, 55, 8, 35, 50, 8, 11, 56, 56, 7, 49, 58, 12, 19, 32, 28, 7, 32, 44, 23, 32, 46, 19, 43, 55, 45, 3, 49, 60, 3, 51, 12, 3, 49, 12, 45, 19, 54, 12, 31, 55, 13, 7, 54, 13, 31, 54, 49, 44, 34, 56, 44, 6, 55, 62, 10, 48, 12, 2, 31, 53, 24, 3, 54, 8, 23, 55, 8, 15, 54, 42, 13, 7, 32, 61, 35, 32, 29, 15, 32, 44, 31, 43, 53, 13, 3, 52, 29, 3, 52, 13, 3, 54, 61, 45, 31, 53, 12, 7, 54, 12, 11, 50, 13, 35, 52, 55, 46, 30, 53, 12, 6, 49, 29, 30, 56, 12, 14, 31, 51, 56, 11, 48, 56, 15, 50, 8, 19, 48, 10, 45, 27, 32, 28, 19, 32, 30, 31, 32, 28, 11, 43, 54, 13, 3, 50, 28, 3, 53, 60, 3, 49, 30, 44, 27, 50, 12, 23, 54, 12, 23, 53, 13, 27, 49, 54, 60, 10, 56, 61, 14, 56, 62, 30, 49, 61, 2, 7, 49, 56, 15, 54, 24, 7, 55, 24, 19
# ...

# %% [markdown]
# 5\. Load the file "user_data.json", filter the data by the "CreditCardType" field equals to "American Express". Than save the data a to CSV.

# %% [markdown]
# 6\. Load the file from this url: [https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1](https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1) with Pandas.
# + Explore the data (see the info of the data)
# + Draw the istogram of the 'class' field. Decribe wath yuou see

# %% [markdown]
# 7\. Load the remote file [https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1](https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1) with Pandas and plot a scatter plot all possible combination of the following fields:
#
#   + features_1
#   + features_2
#   + features_3

# %% [markdown]
# 8\. Load the same file of point 6, and convert the file to json with Pandas.
